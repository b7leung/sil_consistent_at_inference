# %%
import pickle
import pandas as pd

# %%
x = pickle.load(open("eval_meshes_full.pkl", "rb"))
display(x)
# Out:
#       accuracy (mesh)  accuracy2 (mesh)  chamfer (mesh)  chamfer-L1 (mesh)  \
# idx
# 0            0.006977          0.000065             NaN           0.008819
# 1            0.030495          0.001757             NaN           0.035273
# 2            0.005575          0.000041             NaN           0.006786
# 3            0.011175          0.000203             NaN           0.013133
# 4            0.012266          0.000249             NaN           0.013850
# ...               ...               ...             ...                ...
# 8746         0.005382          0.000058             NaN           0.005633
# 8747         0.011071          0.000177             NaN           0.010712
# 8748         0.006872          0.000068             NaN           0.007191
# 8749         0.010356          0.000219             NaN           0.011359
# 8750         0.011260          0.000176             NaN           0.011048
#
# ...

# %%
display(x[x["modelname"] == "d2815e678f173616e6cfc789522bfbab"])
# Out:
#       accuracy (mesh)  accuracy2 (mesh)  chamfer (mesh)  chamfer-L1 (mesh)  \
# idx
# 6959         0.021081          0.000663             NaN           0.017063
#
#       chamfer-L2 (mesh)  class id class name  completeness (mesh)  \
# idx
# 6959           0.000445  03001627      chair             0.013044
#
#       completeness2 (mesh)  iou (mesh)                         modelname  \
# idx
# 6959              0.000227    0.277181  d2815e678f173616e6cfc789522bfbab
#
#       normals (mesh)  normals accuracy (mesh)  normals completeness (mesh)
# idx
# 6959        0.814175                 0.805501                     0.822849

# %%
t = pd.DataFrame()
t = t.append({"test_col": ["hello", "hi", "bye"]}, ignore_index=True)
display(t)
# Out:
#            test_col
# 0  [hello, hi, bye]

# %%
a = [1,2,3]
b = [4,6,4]
a += b
print(a)
# Out:
# [1, 2, 3, 4, 6, 4]
