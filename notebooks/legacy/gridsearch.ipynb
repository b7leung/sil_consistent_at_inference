# %%
# %load_ext autoreload
# %autoreload 2
notebook_fixed_dir = False

# %%
# this cell can only be called once
import os
if not notebook_fixed_dir:
    os.chdir('..')
    notebook_fixed_dir = True
print(os.getcwd())
# Out:
# /home/svcl-oowl/brandon/research/sil_consistent_at_inference

# %%
import pickle
import pprint
import glob

import trimesh
import torch
import pandas as pd
from tqdm.autonotebook import tqdm
from PIL import Image
import numpy as np

from utils import utils
from evaluation import compute_iou_2d, compute_iou_2d_given_pose, compute_iou_3d, compute_chamfer_L1
from utils.visualization_tools import show_refinement_results
from utils.brute_force_pose_est import brute_force_estimate_pose

# %%
gridsearch_exp_name = "instance1"

device = torch.device("cuda:0")
gridsearch_folder = "out/gridsearch/{}".format(gridsearch_exp_name)
gridsearch_results_df = pd.read_pickle(os.path.join(gridsearch_folder, "eval_df.pkl"))
instance = glob.glob(os.path.join(gridsearch_folder, "*.obj"))[0].split('/')[-1].replace(".obj","")

# %%
display(gridsearch_results_df)
# Out:
#        chamfer  chamfer_norm  delta_chamfer  delta_chamfer_norm  delta_iou_3d  \
# 0     0.005458      0.037595       0.001109            0.011972      0.002350
# 1     0.009033      0.038544       0.004685            0.012922     -0.068030
# 2     0.005428      0.025012       0.001079           -0.000610     -0.017495
# 3     0.013041      0.057087       0.008692            0.031464     -0.104045
# 4     0.013251      0.054730       0.008902            0.029107     -0.121570
# ...        ...           ...            ...                 ...           ...
# 1495  0.015830      0.075886       0.011481            0.050263     -0.160604
# 1496  0.004775      0.033277       0.000426            0.007654      0.009724
# 1497  0.006625      0.036830       0.002277            0.011208      0.025450
# 1498  0.014279      0.080245       0.009930            0.054623      0.001739
# 1499  0.010070      0.039191       0.005721            0.013568      0.155631
#
#       delta_iou_3d_norm    iou_3d  iou_3d_norm refinement learning_rate  \
# 0             -0.024232  0.177154     0.174678                   0.0001
# 1             -0.059852  0.106774     0.139058                  0.00085
# 2              0.022757  0.157309     0.221667                  0.00085
# 3             -0.077567  0.070759     0.121343                  0.00085
# 4             -0.040040  0.053234     0.158870                   0.0001
# ...                 ...       ...          ...                      ...
# 1495          -0.092550  0.014200     0.106360                  0.00085
# 1496           0.006974  0.184528     0.205884                    4e-05
# 1497           0.043284  0.200254     0.242194                   0.0001
# 1498          -0.003495  0.176543     0.195415                    4e-05
# 1499           0.094909  0.330435     0.293819                    4e-05
#
#      refinement num_iterations refinement_number  \
# 0                          350               607
# 1                          350               489
# 2                          350                63
# 3                          350               464
# 4                          350               920
# ...                        ...               ...
# 1495                       350               142
# 1496                       350              1117
# 1497                       350               583
# 1498                       350              1025
# 1499                       350              1055
#
#                   semantic_dis_training dis_weight_path  \
# 0     out/2020_09_21--07_10_21_job5/semantic_dis_net...
# 1     out/2020_09_21--07_10_21_job5/semantic_dis_net...
# 2     out/2020_09_21--07_10_21_job5/semantic_dis_net...
# 3     out/2020_09_21--07_10_21_job5/semantic_dis_net...
# 4     out/2020_09_21--07_10_21_job5/semantic_dis_net...
# ...                                                 ...
# 1495  out/2020_09_21--07_10_21_job5/semantic_dis_net...
# 1496  out/2020_09_21--07_10_21_job5/semantic_dis_net...
# 1497  out/2020_09_21--07_10_21_job5/semantic_dis_net...
# 1498  out/2020_09_21--07_10_21_job5/semantic_dis_net...
# 1499  out/2020_09_21--07_10_21_job5/semantic_dis_net...
#
#                   semantic_dis_training gen_weight_path training img_sym_lam  \
# 0     out/2020_09_21--07_10_21_job5/deform_net_weigh...                    0
# 1     out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
# 2     out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
# 3                                                                         75
# 4                                                                          0
# ...                                                 ...                  ...
# 1495                                                                       0
# 1496  out/2020_09_21--07_10_21_job5/deform_net_weigh...                    0
# 1497  out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
# 1498  out/2020_09_21--07_10_21_job5/deform_net_weigh...                    0
# 1499  out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
#
#      training l2_lam training semantic_dis_lam training sil_lam
# 0                100                         2                1
# 1               1000                       100               50
# 2                  1                         0                5
# 3                 10                       100                5
# 4                  0                       100               10
# ...              ...                       ...              ...
# 1495               1                         2              100
# 1496             100                         2                5
# 1497               1                         0               50
# 1498              10                         0               10
# 1499              10                         0                1
#
# [1500 rows x 17 columns]

# %%
filtered_df = gridsearch_results_df[["iou_3d", "refinement_number", "delta_chamfer", "delta_iou_3d", "iou_3d_norm", "delta_iou_3d_norm"]]
filtered_df = filtered_df[filtered_df["delta_iou_3d"]!=-1]
filtered_df.hist(column="delta_iou_3d", bins=100)
#filtered_df.hist(column="iou_3d", bins=100)
filtered_df.hist(column="delta_iou_3d_norm", bins=100)
#filtered_df.hist(column="iou_3d_norm", bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f28afc65630>]],
#       dtype=object)

# %%
# displaying dataframe info for top 15 iou_3d refinements in gridsearch
cols_to_not_show = ["delta_chamfer", "delta_iou_3d", "semantic_dis_training dis_weight_path", "refinement num_iterations" ]
best_refinements_iou3d_df = gridsearch_results_df.sort_values("iou_3d", ascending=False)[:15].drop(cols_to_not_show, axis=1)
best_refinements_iou3d_nums = list(best_refinements_iou3d_df["refinement_number"])
display(best_refinements_iou3d_df)
# Out:
#        chamfer  chamfer_norm  delta_chamfer_norm  delta_iou_3d_norm    iou_3d  \
# 1245  0.009036      0.033326            0.007704           0.140099  0.332509
# 1499  0.010070      0.039191            0.013568           0.094909  0.330435
# 119   0.012398      0.040709            0.015086           0.074038  0.324783
# 852   0.007526      0.045520            0.019897           0.060420  0.321045
# 933   0.006880      0.045627            0.020005           0.153838  0.317343
# 542   0.011273      0.032692            0.007070           0.145532  0.310714
# 1434  0.013469      0.041750            0.016128           0.060113  0.305953
# 280   0.007497      0.043963            0.018341           0.044262  0.293772
# 1302  0.007292      0.043977            0.018355           0.158499  0.282462
# 803   0.011408      0.030564            0.004941           0.149159  0.276114
# 1125  0.007166      0.050718            0.025095          -0.009940  0.269781
# 157   0.011674      0.070739            0.045117           0.017784  0.250833
# 113   0.003609      0.032957            0.007335          -0.022032  0.245646
# 287   0.003521      0.024868           -0.000754           0.053430  0.242696
# 1260  0.011967      0.057162            0.031540           0.004030  0.239394
#
#       iou_3d_norm refinement learning_rate refinement_number  \
# 1245     0.339009                    4e-05              1155
# 1499     0.293819                    4e-05              1055
# 119      0.272948                    4e-05              1053
# 852      0.259331                   0.0001               511
# 933      0.352748                    4e-05              1177
# 542      0.344442                    4e-05              1153
# 1434     0.259023                    4e-05              1051
# 280      0.243172                   0.0001               513
# 1302     0.357409                    4e-05              1077
# 803      0.348069                    4e-05              1151
# 1125     0.188970                   0.0001               505
# 157      0.216694                    4e-05              1045
# 113      0.176878                   0.0001               512
# 287      0.252340                   0.0001               686
# 1260     0.202940                   0.0001               503
#
#                   semantic_dis_training gen_weight_path training img_sym_lam  \
# 1245  out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
# 1499  out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
# 119   out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
# 852   out/2020_09_21--07_10_21_job5/deform_net_weigh...                    0
# 933   out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
# 542   out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
# 1434  out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
# 280   out/2020_09_21--07_10_21_job5/deform_net_weigh...                    0
# 1302  out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
# 803   out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
# 1125  out/2020_09_21--07_10_21_job5/deform_net_weigh...                    0
# 157   out/2020_09_21--07_10_21_job5/deform_net_weigh...                    0
# 113                                                                        0
# 287                                                                       75
# 1260  out/2020_09_21--07_10_21_job5/deform_net_weigh...                    0
#
#      training l2_lam training semantic_dis_lam training sil_lam
# 1245              10                         2                1
# 1499              10                         0                1
# 119                1                         0                1
# 852                0                         0                5
# 933              100                         2               10
# 542                1                         2                1
# 1434               0                         0                1
# 280                1                         0                5
# 1302             100                         0               10
# 803                0                         2                1
# 1125              10                         0                1
# 157               10                         0              100
# 113                1                         0                5
# 287              100                         2               50
# 1260               1                         0                1

# %%
# displaying dataframe info for top 15 iou_3d norm refinements in gridsearch
cols_to_not_show = ["delta_chamfer", "delta_iou_3d", "semantic_dis_training dis_weight_path", "refinement num_iterations" ]
best_refinements_iou3d_norm_df = gridsearch_results_df.sort_values("iou_3d_norm", ascending=False)[:15].drop(cols_to_not_show, axis=1)
best_refinements_iou3d_norm_nums = list(best_refinements_iou3d_norm_df["refinement_number"])
display(best_refinements_iou3d_norm_df)
# Out:
#        chamfer  chamfer_norm  delta_chamfer_norm  delta_iou_3d_norm    iou_3d  \
# 1302  0.007292      0.043977            0.018355           0.158499  0.282462
# 933   0.006880      0.045627            0.020005           0.153838  0.317343
# 803   0.011408      0.030564            0.004941           0.149159  0.276114
# 542   0.011273      0.032692            0.007070           0.145532  0.310714
# 1245  0.009036      0.033326            0.007704           0.140099  0.332509
# 1313  0.009340      0.024622           -0.001001           0.128409  0.193441
# 1030  0.007878      0.027940            0.002317           0.112384  0.222387
# 748   0.007526      0.030424            0.004801           0.104495  0.221653
# 1499  0.010070      0.039191            0.013568           0.094909  0.330435
# 1464  0.005799      0.023466           -0.002157           0.077922  0.153841
# 119   0.012398      0.040709            0.015086           0.074038  0.324783
# 85    0.004447      0.023836           -0.001786           0.069893  0.224762
# 1411  0.005195      0.022172           -0.003451           0.069053  0.175365
# 525   0.004359      0.021449           -0.004174           0.068410  0.192757
# 1490  0.006092      0.024150           -0.001472           0.068337  0.152970
#
#       iou_3d_norm refinement learning_rate refinement_number  \
# 1302     0.357409                    4e-05              1077
# 933      0.352748                    4e-05              1177
# 803      0.348069                    4e-05              1151
# 542      0.344442                    4e-05              1153
# 1245     0.339009                    4e-05              1155
# 1313     0.327319                    4e-05              1251
# 1030     0.311294                    4e-05              1253
# 748      0.303406                    4e-05              1497
# 1499     0.293819                    4e-05              1055
# 1464     0.276832                   0.0001               553
# 119      0.272948                    4e-05              1053
# 85       0.268803                  0.00085                60
# 1411     0.267963                  0.00085                55
# 525      0.267321                  0.00085                57
# 1490     0.267247                   0.0001               653
#
#                   semantic_dis_training gen_weight_path training img_sym_lam  \
# 1302  out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
# 933   out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
# 803   out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
# 542   out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
# 1245  out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
# 1313  out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
# 1030  out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
# 748   out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
# 1499  out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
# 1464  out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
# 119   out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
# 85                                                                        75
# 1411  out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
# 525   out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
# 1490  out/2020_09_21--07_10_21_job5/deform_net_weigh...                   75
#
#      training l2_lam training semantic_dis_lam training sil_lam
# 1302             100                         0               10
# 933              100                         2               10
# 803                0                         2                1
# 542                1                         2                1
# 1245              10                         2                1
# 1313               0                        10                1
# 1030               1                        10                1
# 748              100                       100              100
# 1499              10                         0                1
# 1464               1                         0                1
# 119                1                         0                1
# 85                 0                         0                5
# 1411              10                         0                1
# 525              100                         0                1
# 1490               1                         2                1

# %%
input_image = Image.open(os.path.join(gridsearch_folder, "{}.png".format(instance)))
mesh_original_path = os.path.join(gridsearch_folder, "{}.obj".format(instance))
with torch.no_grad():
    mesh_original = utils.load_untextured_mesh(mesh_original_path, device)
mask = np.asarray(input_image)[:,:,3] > 0
pred_azim, pred_elev, pred_dist, _, _ = brute_force_estimate_pose(mesh_original, mask, 20, 20, 40, device, 8)

# %%
# visualizing top iou3d refinements in gridsearch
for refinement_num in best_refinements_iou3d_nums[:5]:
    mesh_processed_path = os.path.join(gridsearch_folder, "{}_gridsearch".format(instance), "{}.obj".format(refinement_num))
    print(mesh_processed_path)
    with torch.no_grad():
        mesh_processed = utils.load_untextured_mesh(mesh_processed_path, device)
    show_refinement_results(input_image, mesh_original, mesh_processed, pred_dist, pred_elev, pred_azim, device, num_novel_view=3)
# Out:
# out/gridsearch/instance1/0085_gridsearch/1155.obj
# out/gridsearch/instance1/0085_gridsearch/1055.obj
# out/gridsearch/instance1/0085_gridsearch/1053.obj
# out/gridsearch/instance1/0085_gridsearch/511.obj
# out/gridsearch/instance1/0085_gridsearch/1177.obj

# %%
# visualizing top iou3d_norm refinements in gridsearch
for refinement_num in best_refinements_iou3d_norm_nums[:5]:
    mesh_processed_path = os.path.join(gridsearch_folder, "{}_gridsearch".format(instance), "{}.obj".format(refinement_num))
    print(mesh_processed_path)
    with torch.no_grad():
        mesh_processed = utils.load_untextured_mesh(mesh_processed_path, device)
    show_refinement_results(input_image, mesh_original, mesh_processed, pred_dist, pred_elev, pred_azim, device, num_novel_view=3)
# Out:
# out/gridsearch/instance1/0085_gridsearch/1077.obj
# out/gridsearch/instance1/0085_gridsearch/1177.obj
# out/gridsearch/instance1/0085_gridsearch/1151.obj
# out/gridsearch/instance1/0085_gridsearch/1153.obj
# out/gridsearch/instance1/0085_gridsearch/1155.obj

# %% [markdown]
# # Multi Analysis

# %%
avg_df = None
for i in range(1,11):
    gridsearch_exp_name = "instance{}".format(i)
    gridsearch_folder = "out/gridsearch/{}".format(gridsearch_exp_name)
    gridsearch_results_df = pd.read_pickle(os.path.join(gridsearch_folder, "eval_df.pkl"))
    instance = glob.glob(os.path.join(gridsearch_folder, "*.obj"))[0].split('/')[-1].replace(".obj","")
    if avg_df is None:
        avg_df = gridsearch_results_df[["delta_iou_3d", "delta_iou_3d_norm"]]
    else:
        avg_df += gridsearch_results_df[["delta_iou_3d", "delta_iou_3d_norm"]]

display((avg_df/10).sort_values("delta_iou_3d", ascending=False)[:20])
display((avg_df/10).sort_values("delta_iou_3d_norm", ascending=False)[:20])
display((avg_df/10).plot.scatter("delta_iou_3d", "delta_iou_3d_norm"))
# Out:
#       delta_iou_3d  delta_iou_3d_norm
# 843       0.069053           0.055628
# 1009      0.065181           0.041400
# 793       0.062823           0.050802
# 1027      0.062767           0.055859
# 384       0.056097           0.051772
# 467       0.055749           0.064015
# 551       0.053776           0.049296
# 526       0.053664           0.062596
# 604       0.053623           0.027156
# 1062      0.053504           0.030657
# 1045      0.051074           0.042779
# 491       0.050622           0.035603
# 1059      0.050095           0.036823
# 1007      0.048217           0.036651
# 1355      0.048105           0.039764
# 166       0.047792           0.009009
# 652       0.047350           0.050213
# 1164      0.046188           0.032754
# 212       0.046093           0.050966
# 328       0.044819           0.049383
#       delta_iou_3d  delta_iou_3d_norm
# 80        0.020208           0.064056
# 467       0.055749           0.064015
# 526       0.053664           0.062596
# 89        0.042267           0.062178
# 1027      0.062767           0.055859
# 843       0.069053           0.055628
# 193       0.042868           0.055448
# 142       0.035232           0.054453
# 1450      0.041961           0.052594
# 384       0.056097           0.051772
# 212       0.046093           0.050966
# 793       0.062823           0.050802
# 1499      0.018954           0.050634
# 516       0.018572           0.050435
# 652       0.047350           0.050213
# 56        0.021560           0.049771
# 328       0.044819           0.049383
# 551       0.053776           0.049296
# 124       0.038736           0.047024
# 223       0.035149           0.046549

# %%
['refinement learning_rate', 'refinement num_iterations', 'training semantic_dis_lam', 'training img_sym_lam', 'training sil_lam', 'training l2_lam', 'semantic_dis_training gen_weight_path', 'semantic_dis_training dis_weight_path']

843 -- (0.0001, 350, 30, 0, 100, 1, 'out/2020_09_21--07_10_21_job5/deform_net_weights_99.pt', 'out/2020_09_21--07_10_21_job5/semantic_dis_net_weights_99.pt')

#1009 -- (4e-05, 350, 0, 0, 1, 1000, 'out/2020_09_21--07_10_21_job5/deform_net_weights_99.pt', 'out/2020_09_21--07_10_21_job5/semantic_dis_net_weights_99.pt')

1027 -- (4e-05, 350, 0, 0, 10, 100, 'out/2020_09_21--07_10_21_job5/deform_net_weights_99.pt', 'out/2020_09_21--07_10_21_job5/semantic_dis_net_weights_99.pt')

#793 -- (0.0001, 350, 10, 75, 100, 1, 'out/2020_09_21--07_10_21_job5/deform_net_weights_99.pt', 'out/2020_09_21--07_10_21_job5/semantic_dis_net_weights_99.pt')

#467 -- (0.00085, 350, 100, 75, 5, 100, 'out/2020_09_21--07_10_21_job5/deform_net_weights_99.pt', 'out/2020_09_21--07_10_21_job5/semantic_dis_net_weights_99.pt')
